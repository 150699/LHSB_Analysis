# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.0 MB 10.6 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/11.0 MB 10.2 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.0 MB 9.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.9/11.0 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 9.4 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    ------ --------------------------------- 2.1/12.8 MB 10.7 MB/s eta 0:00:01
#    ------------- -------------------------- 4.2/12.8 MB 10.4 MB/s eta 0:00:01
#    -------------------- ------------------- 6.6/12.8 MB 10.2 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.8 MB 10.3 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np
